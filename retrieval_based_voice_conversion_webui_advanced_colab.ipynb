# %% [markdown]
# <a href="https://colab.research.google.com/github/SantosCristiano/artificial-intelligence-python/blob/main/retrieval_based_voice_conversion_webui_advanced_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# %env TF_CPP_MIN_LOG_LEVEL=1
# !apt -y install -qq aria2
# !pip install -q faiss-gpu fairseq gradio==3.14.0 ffmpeg ffmpeg-python praat-parselmouth pyworld numpy==1.23.5 numba==0.56.4 librosa==0.9.2 tensorboardX mega.py gdown

# !git clone https://github.com/toticavalcanti/Retrieval-based-Voice-Conversion-WebUI
# %cd /content/Retrieval-based-Voice-Conversion-WebUI

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/D32k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/D40k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/D48k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/G32k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/G40k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/G48k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o G48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/f0D32k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o f0D32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/f0D40k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o f0D40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/f0D48k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o f0D48k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/f0G32k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o f0G32k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/f0G40k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o f0G40k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/pretrained/f0G48k.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/pretrained -o f0G48k.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/uvr5_weights/HP2-人声vocals+非人声instrumentals.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/uvr5_weights -o HP2-人声vocals+非人声instrumentals.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/uvr5_weights -o HP5-主旋律人声vocals+其他instrumentals.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/VoiceConversionWebUI/resolve/main/hubert_base.pt -d /content/Retrieval-based-Voice-Conversion-WebUI -o hubert_base.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/Benee-RVC/resolve/main/BENEE8000.pth -d /content/Retrieval-based-Voice-Conversion-WebUI/weights -o Benee-RVC.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/Benee-RVC/resolve/main/added_IVF1054_Flat_nprobe_8.index -d /content/Retrieval-based-Voice-Conversion-WebUI/logs/Benee-RVC -o added_IVF1054_Flat_nprobe_8.index
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/Benee-RVC/resolve/main/total_fea.npy -d /content/Retrieval-based-Voice-Conversion-WebUI/logs/Benee-RVC -o total_fea.npy

# !python infer-web.py --colab
# Out:
# /content
# env: TF_CPP_MIN_LOG_LEVEL=1
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 18 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 120875 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 102.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 102.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 kB 30.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 274.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 96.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 98.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.5/286.5 kB 29.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
#   Building wheel for fairseq (pyproject.toml) ... done
#   Building wheel for ffmpeg (setup.py) ... done
#   Building wheel for pyworld (pyproject.toml) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotly 5.15.0 requires tenacity>=6.2.0, but you have tenacity 5.1.5 which is incompatible.
# Cloning into 'Retrieval-based-Voice-Conversion-WebUI'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 203 (delta 32), reused 33 (delta 27), pack-reused 130
# Receiving objects: 100% (203/203), 98.25 MiB | 25.91 MiB/s, done.
# Resolving deltas: 100% (60/60), done.
# /content/Retrieval-based-Voice-Conversion-WebUI
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2dc71b|OK  |    63MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 56ff33|OK  |   216MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a82b91|OK  |   218MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0466b0|OK  |    52MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/G32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7354a0|OK  |    54MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 433731|OK  |   196MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/G48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 861be9|OK  |   230MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/f0D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a726de|OK  |   182MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/f0D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ff3f1e|OK  |    75MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/f0D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 269665|OK  |    44MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/f0G32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 391b6c|OK  |    48MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/f0G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 13c695|OK  |    50MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/pretrained/f0G48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5e97e0|OK  |    45MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/uvr5_weights/HP2-人声vocals+非人声instrumentals.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# bd56ef|OK  |    27MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6b30a3|OK  |   101MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/hubert_base.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8f06bb|OK  |    39MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/weights/Benee-RVC.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a87fd5|OK  |    32MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/logs/Benee-RVC/added_IVF1054_Flat_nprobe_8.index
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f8dae5|OK  |   110MiB/s|/content/Retrieval-based-Voice-Conversion-WebUI/logs/Benee-RVC/total_fea.npy
#
# Status Legend:
# (OK):download completed.
# Use Language: en_US
# 2023-10-08 19:36:02.194620: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running on local URL:  http://127.0.0.1:7860
#
# Setting up a public link... we have recently upgraded the way public links are generated. If you encounter any problems, please report the issue and downgrade to gradio version 3.13.0
# .
# Running on public URL: https://e11d61f8-a1ca-4247.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# 2023-10-08 19:38:42 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 19:38:42 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/reset "HTTP/1.1 200 OK"
# 2023-10-08 19:38:54 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 19:38:54 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# start preprocess
# ['trainset_preprocess_pipeline_print.py', '/content/sample_data/sting', '48000', '2', '/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100', 'False']
# /content/sample_data/sting/Fields Of Gold-vocals-D major-102bpm-440hz.mp3->Suc.
# /content/sample_data/sting/Sting - It's Probably Me (Official Music Video)-vocals-E minor-92bpm-441hz.mp3->Suc.
# /content/sample_data/sting/english-in-new-york-vocals-B minor-102bpm-441hz.mp3->Suc.
# /content/sample_data/sting/music01-vocals-D major-112bpm-440hz.mp3->Suc.
# /content/sample_data/sting/x2mate.com - Sting Gives Dave The PG-Version Of How He Got His Name _ Letterman (128 kbps).mp3->Suc.
# /content/sample_data/sting/x2mate.com - The Police - Walking On The Moon (Official Music Video) (128 kbps)-vocals-D minor-146bpm-440hz.mp3->Suc.
# /content/sample_data/sting/Sting - If I Ever Lose My Faith In You (Official Music Video)-vocals-A major-98bpm-441hz.mp3->Suc.
# /content/sample_data/sting/Sting - Seven Days-vocals-C major-92bpm-442hz.mp3->Suc.
# /content/sample_data/sting/intro-interview.mp3->Suc.
# /content/sample_data/sting/x2mate.com - King Of Pain (128 kbps)-vocals-D major-123bpm-442hz.mp3->Suc.
# /content/sample_data/sting/x2mate.com - The Police - Synchronicity II (Official Music Video) (128 kbps)-vocals-A major-159bpm-441hz.mp3->Suc.
# /content/sample_data/sting/x2mate.com-Sting Lived in a Haunted House and Definitely Believes in Ghosts Now.mp3->Suc.
# end preprocess
# start preprocess
# ['trainset_preprocess_pipeline_print.py', '/content/sample_data/sting', '48000', '2', '/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100', 'False']
# /content/sample_data/sting/Fields Of Gold-vocals-D major-102bpm-440hz.mp3->Suc.
# /content/sample_data/sting/Sting - It's Probably Me (Official Music Video)-vocals-E minor-92bpm-441hz.mp3->Suc.
# /content/sample_data/sting/english-in-new-york-vocals-B minor-102bpm-441hz.mp3->Suc.
# /content/sample_data/sting/music01-vocals-D major-112bpm-440hz.mp3->Suc.
# /content/sample_data/sting/x2mate.com - Sting Gives Dave The PG-Version Of How He Got His Name _ Letterman (128 kbps).mp3->Suc.
# /content/sample_data/sting/x2mate.com - The Police - Walking On The Moon (Official Music Video) (128 kbps)-vocals-D minor-146bpm-440hz.mp3->Suc.
# /content/sample_data/sting/Sting - If I Ever Lose My Faith In You (Official Music Video)-vocals-A major-98bpm-441hz.mp3->Suc.
# /content/sample_data/sting/Sting - Seven Days-vocals-C major-92bpm-442hz.mp3->Suc.
# /content/sample_data/sting/intro-interview.mp3->Suc.
# /content/sample_data/sting/x2mate.com - King Of Pain (128 kbps)-vocals-D major-123bpm-442hz.mp3->Suc.
# /content/sample_data/sting/x2mate.com - The Police - Synchronicity II (Official Music Video) (128 kbps)-vocals-A major-159bpm-441hz.mp3->Suc.
# /content/sample_data/sting/x2mate.com-Sting Lived in a Haunted House and Definitely Believes in Ghosts Now.mp3->Suc.
# end preprocess
#
# 2023-10-08 19:39:36 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 19:39:36 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# ['extract_f0_print.py', '/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100', '2', 'harvest']
# todo-f0-187
# f0ing,now-0,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/0_0.wav
# /content/Retrieval-based-Voice-Conversion-WebUI/extract_f0_print.py:38: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   x, sr = librosa.load(path, self.fs)  # , res_type='soxr_vhq'
# todo-f0-186
# f0ing,now-0,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/0_10.wav
# /content/Retrieval-based-Voice-Conversion-WebUI/extract_f0_print.py:38: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   x, sr = librosa.load(path, self.fs)  # , res_type='soxr_vhq'
# /content/Retrieval-based-Voice-Conversion-WebUI/extract_f0_print.py:89: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   f0_coarse = np.rint(f0_mel).astype(np.int)
# /content/Retrieval-based-Voice-Conversion-WebUI/extract_f0_print.py:38: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   x, sr = librosa.load(path, self.fs)  # , res_type='soxr_vhq'
# /content/Retrieval-based-Voice-Conversion-WebUI/extract_f0_print.py:89: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   f0_coarse = np.rint(f0_mel).astype(np.int)
# /content/Retrieval-based-Voice-Conversion-WebUI/extract_f0_print.py:38: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   x, sr = librosa.load(path, self.fs)  # , res_type='soxr_vhq'
# f0ing,now-37,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/11_11.wav
# f0ing,now-37,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/11_10.wav
# f0ing,now-74,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/2_41.wav
# f0ing,now-74,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/2_40.wav
# f0ing,now-111,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/3_69.wav
# f0ing,now-111,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/3_68.wav
# f0ing,now-148,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/7_6.wav
# f0ing,now-148,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/7_48.wav
# f0ing,now-185,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/9_6.wav
# f0ing,now-185,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/9_55.wav
# ['extract_f0_print.py', '/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100', '2', 'harvest']
# todo-f0-187
# f0ing,now-0,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/0_0.wav
# todo-f0-186
# f0ing,now-0,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/0_10.wav
# f0ing,now-37,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/11_11.wav
# f0ing,now-37,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/11_10.wav
# f0ing,now-74,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/2_41.wav
# f0ing,now-74,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/2_40.wav
# f0ing,now-111,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/3_69.wav
# f0ing,now-111,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/3_68.wav
# f0ing,now-148,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/7_6.wav
# f0ing,now-148,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/7_48.wav
# f0ing,now-185,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/9_6.wav
# f0ing,now-185,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/9_55.wav
#
# 2023-10-08 19:47:19 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 19:47:19 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 19:47:22.557092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ['extract_feature_print.py', 'cuda:0', '1', '0', '0', '/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100']
# /content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100
# load model(s) from hubert_base.pt
# 2023-10-08 19:47:25 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/Retrieval-based-Voice-Conversion-WebUI
# 2023-10-08 19:47:25 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2023-10-08 19:47:25 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# move model to cuda
# all-feature-373
# now-373,all-0,0_0.wav,(184, 256)
# now-373,all-37,10_16.wav,(184, 256)
# now-373,all-74,11_10.wav,(156, 256)
# now-373,all-111,1_27.wav,(47, 256)
# now-373,all-148,2_40.wav,(95, 256)
# now-373,all-185,3_26.wav,(184, 256)
# now-373,all-222,3_68.wav,(149, 256)
# now-373,all-259,6_7.wav,(184, 256)
# now-373,all-296,7_48.wav,(47, 256)
# now-373,all-333,8_50.wav,(184, 256)
# now-373,all-370,9_55.wav,(102, 256)
# all-feature-done
# ['extract_f0_print.py', '/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100', '2', 'harvest']
# todo-f0-187
# f0ing,now-0,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/0_0.wav
# todo-f0-186
# f0ing,now-0,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/0_10.wav
# f0ing,now-37,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/11_11.wav
# f0ing,now-37,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/11_10.wav
# f0ing,now-74,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/2_41.wav
# f0ing,now-74,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/2_40.wav
# f0ing,now-111,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/3_69.wav
# f0ing,now-111,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/3_68.wav
# f0ing,now-148,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/7_6.wav
# f0ing,now-148,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/7_48.wav
# f0ing,now-185,all-186,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/9_6.wav
# f0ing,now-185,all-187,-/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100/1_16k_wavs/9_55.wav
# ['extract_feature_print.py', 'cuda:0', '1', '0', '0', '/content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100']
# /content/Retrieval-based-Voice-Conversion-WebUI/logs/sting-e100
# load model(s) from hubert_base.pt
# move model to cuda
# all-feature-373
# now-373,all-0,0_0.wav,(184, 256)
# now-373,all-37,10_16.wav,(184, 256)
# now-373,all-74,11_10.wav,(156, 256)
# now-373,all-111,1_27.wav,(47, 256)
# now-373,all-148,2_40.wav,(95, 256)
# now-373,all-185,3_26.wav,(184, 256)
# now-373,all-222,3_68.wav,(149, 256)
# now-373,all-259,6_7.wav,(184, 256)
# now-373,all-296,7_48.wav,(47, 256)
# now-373,all-333,8_50.wav,(184, 256)
# now-373,all-370,9_55.wav,(102, 256)
# all-feature-done
#
# 2023-10-08 19:47:40 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 19:47:40 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 19:47:40 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-10-08 19:47:43.497481: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.10/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.xla_bridge:No jax_plugins namespace packages available
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-10-08 19:47:48.516932: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.10/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.xla_bridge:No jax_plugins namespace packages available
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:sting-e100:{'train': {'log_interval': 200, 'seed': 1234, 'epochs': 20000, 'learning_rate': 0.0001, 'betas': [0.8, 0.99], 'eps': 1e-09, 'batch_size': 7, 'fp16_run': True, 'lr_decay': 0.999875, 'segment_size': 11520, 'init_lr_ratio': 1, 'warmup_epochs': 0, 'c_mel': 45, 'c_kl': 1.0}, 'data': {'max_wav_value': 32768.0, 'sampling_rate': 48000, 'filter_length': 2048, 'hop_length': 480, 'win_length': 2048, 'n_mel_channels': 128, 'mel_fmin': 0.0, 'mel_fmax': None, 'training_files': './logs/sting-e100/filelist.txt'}, 'model': {'inter_channels': 192, 'hidden_channels': 192, 'filter_channels': 768, 'n_heads': 2, 'n_layers': 6, 'kernel_size': 3, 'p_dropout': 0, 'resblock': '1', 'resblock_kernel_sizes': [3, 7, 11], 'resblock_dilation_sizes': [[1, 3, 5], [1, 3, 5], [1, 3, 5]], 'upsample_rates': [10, 6, 2, 2, 2], 'upsample_initial_channel': 512, 'upsample_kernel_sizes': [16, 16, 4, 4, 4], 'use_spectral_norm': False, 'gin_channels': 256, 'spk_embed_dim': 109}, 'model_dir': './logs/sting-e100', 'experiment_dir': './logs/sting-e100', 'save_every_epoch': 5, 'name': 'sting-e100', 'total_epoch': 100, 'pretrainG': 'pretrained/f0G48k.pth', 'pretrainD': 'pretrained/f0D48k.pth', 'gpus': '0', 'sample_rate': '48k', 'if_f0': 1, 'if_latest': 0, 'if_cache_data_in_gpu': 0}
# WARNING:sting-e100:/content/Retrieval-based-Voice-Conversion-WebUI/train is not a git repository, therefore hash value comparison will be ignored.
# INFO:torch.distributed.distributed_c10d:Added key: store_based_barrier_key:1 to store for rank: 0
# INFO:torch.distributed.distributed_c10d:Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# gin_channels: 256 self.spk_embed_dim: 109
# INFO:sting-e100:loaded pretrained pretrained/f0G48k.pth pretrained/f0D48k.pth
# <All keys matched successfully>
# <All keys matched successfully>
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-10-08 19:47:56.772894: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.10/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.xla_bridge:No jax_plugins namespace packages available
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-10-08 19:48:01.905530: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.10/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.xla_bridge:No jax_plugins namespace packages available
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-10-08 19:48:07.811011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.10/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.xla_bridge:No jax_plugins namespace packages available
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-10-08 19:48:13.395599: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.10/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.xla_bridge:No jax_plugins namespace packages available
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# min value is  tensor(-1.0282)
# min value is  tensor(-1.0055)
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# INFO:torch.nn.parallel.distributed:Reducer buckets have been rebuilt in this iteration.
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py:200: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [32, 1, 4], strides() = [4, 1, 1]
# bucket_view.sizes() = [32, 1, 4], strides() = [4, 4, 1] (Triggered internally at ../torch/csrc/distributed/c10d/reducer.cpp:323.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# INFO:sting-e100:Train Epoch: 1 [0%]
# INFO:sting-e100:[0, 0.0001]
# INFO:sting-e100:loss_disc=2.513, loss_gen=2.391, loss_fm=8.272,loss_mel=34.440, loss_kl=5.000
# DEBUG:matplotlib:matplotlib data path: /usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# INFO:torch.nn.parallel.distributed:Reducer buckets have been rebuilt in this iteration.
# min value is  tensor(-1.0157)
# min value is  tensor(-1.0396)
# INFO:sting-e100:====> Epoch: 1
# INFO:sting-e100:====> Epoch: 2
# INFO:sting-e100:====> Epoch: 3
# INFO:sting-e100:Train Epoch: 4 [57%]
# INFO:sting-e100:[200, 9.996250468730469e-05]
# INFO:sting-e100:loss_disc=1.632, loss_gen=5.352, loss_fm=13.550,loss_mel=26.985, loss_kl=2.091
# INFO:sting-e100:====> Epoch: 4
# INFO:sting-e100:Saving model and optimizer state at epoch 5 to ./logs/sting-e100/G_280.pth
# INFO:sting-e100:Saving model and optimizer state at epoch 5 to ./logs/sting-e100/D_280.pth
# INFO:sting-e100:====> Epoch: 5
# INFO:sting-e100:====> Epoch: 6
# INFO:sting-e100:====> Epoch: 7
# INFO:sting-e100:Train Epoch: 8 [14%]
# INFO:sting-e100:[400, 9.991253280566489e-05]
# INFO:sting-e100:loss_disc=1.370, loss_gen=5.499, loss_fm=16.361,loss_mel=26.498, loss_kl=2.141
# INFO:sting-e100:====> Epoch: 8
# INFO:sting-e100:====> Epoch: 9
# INFO:sting-e100:Saving model and optimizer state at epoch 10 to ./logs/sting-e100/G_560.pth
# INFO:sting-e100:Saving model and optimizer state at epoch 10 to ./logs/sting-e100/D_560.pth
# INFO:sting-e100:====> Epoch: 10
# INFO:sting-e100:Train Epoch: 11 [71%]
# INFO:sting-e100:[600, 9.987507028906759e-05]
# INFO:sting-e100:loss_disc=0.924, loss_gen=5.853, loss_fm=16.835,loss_mel=26.025, loss_kl=1.909
# INFO:sting-e100:====> Epoch: 11
# INFO:sting-e100:====> Epoch: 12
# INFO:sting-e100:====> Epoch: 13
# INFO:sting-e100:====> Epoch: 14
# INFO:sting-e100:Train Epoch: 15 [29%]
# INFO:sting-e100:[800, 9.982514211643064e-05]
# INFO:sting-e100:loss_disc=0.904, loss_gen=5.759, loss_fm=17.125,loss_mel=25.792, loss_kl=1.590
# INFO:sting-e100:Saving model and optimizer state at epoch 15 to ./logs/sting-e100/G_840.pth
# INFO:sting-e100:Saving model and optimizer state at epoch
pth
# INFO:sting-e100:Saving model and optimizer state at epoch 85 to ./logs/sting-e100/D_4760.pth
# INFO:sting-e100:====> Epoch: 85
# INFO:sting-e100:Train Epoch: 86 [71%]
# INFO:sting-e100:[4800, 9.894305888331732e-05]
# INFO:sting-e100:loss_disc=1.373, loss_gen=5.143, loss_fm=15.230,loss_mel=23.772, loss_kl=0.925
# INFO:sting-e100:====> Epoch: 86
# INFO:sting-e100:====> Epoch: 87
# INFO:sting-e100:====> Epoch: 88
# INFO:sting-e100:====> Epoch: 89
# INFO:sting-e100:Train Epoch: 90 [29%]
# INFO:sting-e100:[5000, 9.889359662901445e-05]
# INFO:sting-e100:loss_disc=1.014, loss_gen=5.512, loss_fm=16.120,loss_mel=23.453, loss_kl=1.023
# INFO:sting-e100:Saving model and optimizer state at epoch 90 to ./logs/sting-e100/G_5040.pth
# INFO:sting-e100:Saving model and optimizer state at epoch 90 to ./logs/sting-e100/D_5040.pth
# INFO:sting-e100:====> Epoch: 90
# INFO:sting-e100:====> Epoch: 91
# INFO:sting-e100:====> Epoch: 92
# INFO:sting-e100:Train Epoch: 93 [86%]
# INFO:sting-e100:[5200, 9.885651616572276e-05]
# INFO:sting-e100:loss_disc=2.046, loss_gen=4.013, loss_fm=12.687,loss_mel=24.406, loss_kl=1.479
# INFO:sting-e100:====> Epoch: 93
# INFO:sting-e100:====> Epoch: 94
# INFO:sting-e100:Saving model and optimizer state at epoch 95 to ./logs/sting-e100/G_5320.pth
# INFO:sting-e100:Saving model and optimizer state at epoch 95 to ./logs/sting-e100/D_5320.pth
# INFO:sting-e100:====> Epoch: 95
# INFO:sting-e100:====> Epoch: 96
# INFO:sting-e100:Train Epoch: 97 [43%]
# INFO:sting-e100:[5400, 9.880709717466598e-05]
# INFO:sting-e100:loss_disc=0.919, loss_gen=5.636, loss_fm=17.790,loss_mel=24.073, loss_kl=1.017
# INFO:sting-e100:====> Epoch: 97
# INFO:sting-e100:====> Epoch: 98
# INFO:sting-e100:====> Epoch: 99
# INFO:sting-e100:Saving model and optimizer state at epoch 100 to ./logs/sting-e100/G_5600.pth
# INFO:sting-e100:Saving model and optimizer state at epoch 100 to ./logs/sting-e100/D_5600.pth
# INFO:sting-e100:====> Epoch: 100
# INFO:sting-e100:Training is done. The program is closed.
# INFO:sting-e100:saving final ckpt:Success.
# Traceback (most recent call last):
#   File "/content/Retrieval-based-Voice-Conversion-WebUI/train_nsf_sim_cache_sid_load_pretrain.py", line 534, in <module>
#     main()
#   File "/content/Retrieval-based-Voice-Conversion-WebUI/train_nsf_sim_cache_sid_load_pretrain.py", line 50, in main
#     mp.spawn(
#   File "/usr/local/lib/python3.10/dist-packages/torch/multiprocessing/spawn.py", line 239, in spawn
#     return start_processes(fn, args, nprocs, join, daemon, start_method='spawn')
#   File "/usr/local/lib/python3.10/dist-packages/torch/multiprocessing/spawn.py", line 197, in start_processes
#     while not context.join():
#   File "/usr/local/lib/python3.10/dist-packages/torch/multiprocessing/spawn.py", line 149, in join
#     raise ProcessExitedException(
# torch.multiprocessing.spawn.ProcessExitedException: process 0 terminated with exit code 149
# 2023-10-08 20:40:32 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 20:40:32 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 20:40:32 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# /usr/lib/python3.10/multiprocessing/resource_tracker.py:224: UserWarning: resource_tracker: There appear to be 20 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# 2023-10-08 20:40:42 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 20:40:44 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 20:40:44 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 20:40:44 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/api/predict "HTTP/1.1 200 OK"
# 2023-10-08 20:40:44 | INFO | httpx | HTTP Request: POST http://127.0.0.1:7860/reset "HTTP/1.1 200 OK"
